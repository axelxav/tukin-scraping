# %% [markdown]
# # import library

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./merge_tweets.csv')

# %% [markdown]
# # import dataset

# %%
df = pd.read_csv('./tweets/tweets.csv')
df1 = pd.read_csv('./tweets/tweets1.csv')
df2 = pd.read_csv('./tweets/tweets2.csv')
df3 = pd.read_csv('./tweets/tweets3.csv')
df4 = pd.read_csv('./tweets/tweets4.csv')
df5 = pd.read_csv('./tweets/tweets5.csv')
df6 = pd.read_csv('./tweets/tweets6.csv')
df7 = pd.read_csv('./tweets/tweets7.csv')
df8 = pd.read_csv('./tweets/tweets8.csv')
df9 = pd.read_csv('./tweets/tweets9.csv')
df10 = pd.read_csv('./tweets/tweets10.csv')
df11 = pd.read_csv('./tweets/tweets11.csv')
df12 = pd.read_csv('./tweets/tweets12.csv')
df13 = pd.read_csv('./tweets/tweets13.csv')

# %% [markdown]
# # data preparation

# %%
# combine df and df1
df = pd.concat([df, df13], ignore_index=True)

# check for duplication based on 'id' column
df.drop_duplicates(subset='id', inplace=True)
# reset index
df.reset_index(drop=True, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1933 entries, 0 to 1932
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1933 non-null   int64
#  1   created_at      1933 non-null   object
#  2   user            1933 non-null   object
#  3   location        1465 non-null   object
#  4   text            1933 non-null   object
#  5   in_reply_to     807 non-null    float64
#  6   reply_count     1933 non-null   int64
#  7   favorite_count  1933 non-null   int64
#  8   hashtags        1933 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 136.0+ KB

# %%
df.to_csv('./merge_tweets.csv', index=False)
display(df)
# Out:
#                        id                 created_at  \
# 0     1876123215170576814  2025-01-06 04:26:45+00:00
# 1     1876125153870123456  2025-01-06 04:34:28+00:00
# 2     1876105868288401730  2025-01-06 03:17:50+00:00
# 3     1876228172611739753  2025-01-06 11:23:49+00:00
# 4     1876117786143158289  2025-01-06 04:05:11+00:00
# ...                   ...                        ...
# 1928  1886222669437448255  2025-02-03 01:18:23+00:00
# 1929  1886445734322671796  2025-02-03 16:04:46+00:00
# 1930  1886226974206775748  2025-02-03 01:35:29+00:00
# 1931  1886288062256497091  2025-02-03 05:38:14+00:00
# 1932  1886296529323114933  2025-02-03 06:11:52+00:00
#
#                                            user               location  \
# 0     Pejuang Tukin Dosen ASN Kemendiktisaintek  Negara tanpa Keadilan
# 1     Pejuang Tukin Dosen ASN Kemendiktisaintek  Negara tanpa Keadilan
# 2     Pejuang Tukin Dosen ASN Kemendiktisaintek  Negara tanpa Keadilan
# ...
